# %%
import numpy as np
import time
import sys
import random as rand

# %%
def delayPrint(seconds):
    for i in seconds:
        sys.stdout.write(i)
        sys.stdout.flush()
        time.sleep(0.05)

# %%
class Pokemon:
    def __init__(self, name, poke_type, poke_moves, poke_stats, health = "========================="):
        self.name = name
        self.type = poke_type
        self.moves = poke_moves
        self.attack = poke_stats['Attack']
        self.specialAttack = poke_stats['Special Attack']
        self.defense = poke_stats['Defense']
        self.specialDefense = poke_stats['Special Defense']
        self.speed = poke_stats['Speed']
        self.health = health
        self.healthbar = 25 #Number of Health '='
    
    def battle(self, Poke_Opponent):
        print("-----POKEMON BATTLE-----\n")
        
        print(f"{self.name}\n")
        print("TYPE->",self.type)
        print("ATTACK: ",self.attack)
        print("SPECIAL ATTACK: ",self.specialAttack)
        print("SPECIAL DEFENSE: ",self.specialDefense)
        print("DEFENSE: ",self.defense)
        print("SPEED: ",self.speed)
        print("Lv. ", 3*(1+np.mean([self.attack,self.specialAttack,
                                    self.defense,self.specialDefense,self.speed]))) # Level Algorithm
        
        print("VS")
        
        print(f"{Poke_Opponent.name}\n")
        print("TYPE->",Poke_Opponent.type)
        print("ATTACK: ",Poke_Opponent.attack)
        print("SPECIAL ATTACK: ",Poke_Opponent.specialAttack)
        print("SPECIAL DEFENSE: ",Poke_Opponent.specialDefense)
        print("DEFENSE: ",Poke_Opponent.defense)
        print("SPEED: ",Poke_Opponent.speed)
        print("Lv. ", 3*(1+np.mean([Poke_Opponent.attack,Poke_Opponent.specialAttack,
                                    Poke_Opponent.defense,Poke_Opponent.specialDefense,Poke_Opponent.speed])))
        
        time.sleep(1)
        
        type_list = ['Fire','Water','Grass','Normal','Electric','Ice','Fighting','Poison','Ground','Flying','Psychic',
                 'Bug','Rock','Ghost','Dragon']
        #FIRE
        if self.type == type_list[0]:
            #Player1 Pokemon is Super Effective!
            if Poke_Opponent.type == type_list[2] or Poke_Opponent.type == type_list[5] or Poke_Opponent.type == type_list[11]:
                self.attack *= 2
                self.specialAttack *= 2
                self.defense *= 2
                self.specialDefense *= 2
                
                Poke_Opponent.attack /= 2
                Poke_Opponent.specialAttack /= 2
                Poke_Opponent.defense /= 2
                Poke_Opponent.specialDefense /= 2
                atk1_output = "\nIt's super effective!"
                atk2_output = "\nIt's not very effective..."
            
            #Player1 Pokemon is not very effective...
            if Poke_Opponent.type == type_list[1] or Poke_Opponent.type == type_list[12] or Poke_Opponent.type == type_list[14]:
                Poke_Opponent.attack *= 2
                Poke_Opponent.specialAttack *= 2
                Poke_Opponent.defense *= 2
                Poke_Opponent.specialDefense *=2 
                
                self.attack /= 2
                self.specialAttack /= 2
                self.defense /= 2
                self.specialDefense /= 2
                atk1_output = "\nIt's not very effective..." 
                atk2_output = "\nIt's super effective!"
                
            #Both Pokemon are the same type
            if Poke_Opponent.type == self.type:
                atk1_output = "\nIt's not very effective..."
                atk2_output = "\nIt's not very effective..."
                
            #else:
                atk1_output = "\nIt did damage!"
                atk2_output = "\nIt did damage!"
        
        #WATER    
        if self.type == type_list[1]:
            #Player1 Pokemon is Super Effective!
            if Poke_Opponent.type == type_list[0] or Poke_Opponent.type == type_list[8] or Poke_Opponent.type == type_list[12]:
                self.attack *= 2
                self.specialAttack *= 2
                self.defense *= 2
                self.specialDefense *= 2
                
                Poke_Opponent.attack /= 2
                Poke_Opponent.specialAttack /= 2
                Poke_Opponent.defense /= 2
                Poke_Opponent.specialDefense /= 2
                atk1_output = "\nIt's super effective!"
                atk2_output = "\nIt's not very effective..."
            
            #Player1 Pokemon is not very effective...
            if Poke_Opponent.type == type_list[2] or Poke_Opponent.type == type_list[14]:
                Poke_Opponent.attack *= 2
                Poke_Opponent.specialAttack *= 2
                Poke_Opponent.defense *= 2
                Poke_Opponent.specialDefense *=2 
                
                self.attack /= 2
                self.specialAttack /= 2
                self.defense /= 2
                self.specialDefense /= 2
                atk1_output = "\nIt's not very effective..." 
                atk2_output = "\nIt's super effective!"
                
            #Both Pokemon are the same type
            if Poke_Opponent.type == self.type:
                atk1_output = "\nIt's not very effective..."
                atk2_output = "\nIt's not very effective..."
                
            else:
                atk1_output = "\nIt did damage!"
                atk2_output = "\nIt did damage!"
        
        #GRASS      
        if self.type == type_list[3]:
            #Player1 Pokemon is Super Effective!
            if Poke_Opponent.type == type_list[1] or Poke_Opponent.type == type_list[8] or Poke_Opponent.type == type_list[12]:
                self.attack *= 2
                self.specialAttack *= 2
                self.defense *= 2
                self.specialDefense *= 2
                
                Poke_Opponent.attack /= 2
                Poke_Opponent.specialAttack /= 2
                Poke_Opponent.defense /= 2
                Poke_Opponent.specialDefense /= 2
                atk1_output = "\nIt's super effective!"
                atk2_output = "\nIt's not very effective..."
            
            #Player1 Pokemon is not very effective...
            if Poke_Opponent.type == type_list[0] or Poke_Opponent.type == type_list[7] or Poke_Opponent.type == type_list[9] or Poke_Opponent.type == type_list[11] or Poke_Opponent.type == type_list[14]:
                Poke_Opponent.attack *= 2
                Poke_Opponent.specialAttack *= 2
                Poke_Opponent.defense *= 2
                Poke_Opponent.specialDefense *=2 
                
                self.attack /= 2
                self.specialAttack /= 2
                self.defense /= 2
                self.specialDefense /= 2
                atk1_output = "\nIt's not very effective..." 
                atk2_output = "\nIt's super effective!"
                
            #Both Pokemon are the same type
            if Poke_Opponent.type == self.type:
                atk1_output = "\nIt's not very effective..."
                atk2_output = "\nIt's not very effective..."
            
            else:
                atk1_output = "\nIt did damage!"
                atk2_output = "\nIt did damage!"
        
        #NORMAL        
        if self.type == type_list[3]:
            
            #Player1 Pokemon is not very effective...
            if Poke_Opponent.type == type_list[12] or Poke_Opponent.type == type_list[13]:
                Poke_Opponent.attack *= 2
                Poke_Opponent.specialAttack *= 2
                Poke_Opponent.defense *= 2
                Poke_Opponent.specialDefense *=2 
                
                self.attack /= 2
                self.specialAttack /= 2
                self.defense /= 2
                self.specialDefense /= 2
                atk1_output = "\nIt's not very effective..." 
                atk2_output = "\nIt's super effective!"
                
                
            #Both Pokemon are the same type
            if Poke_Opponent.type == self.type:
                atk1_output = "\nIt's not very effective..."
                atk2_output = "\nIt's not very effective..."
                
            else:
                atk1_output = "\nIt did damage!"
                atk2_output = "\nIt did damage!"
        
        #ELECTRIC  
        if self.type == type_list[4]:
            #Player1 Pokemon is Super Effective!
            if Poke_Opponent.type == type_list[1] or Poke_Opponent.type == type_list[9]:
                self.attack *= 2
                self.specialAttack *= 2
                self.defense *= 2
                self.specialDefense *= 2
                
                Poke_Opponent.attack /= 2
                Poke_Opponent.specialAttack /= 2
                Poke_Opponent.defense /= 2
                Poke_Opponent.specialDefense /= 2
                atk1_output = "\nIt's super effective!"
                atk2_output = "\nIt's not very effective..."
            
            #Player1 Pokemon is not very effective...
            if Poke_Opponent.type == type_list[2] or Poke_Opponent.type == type_list[14] or Poke_Opponent.type == type_list[8]:
                Poke_Opponent.attack *= 2
                Poke_Opponent.specialAttack *= 2
                Poke_Opponent.defense *= 2
                Poke_Opponent.specialDefense *=2 
                
                self.attack /= 2
                self.specialAttack /= 2
                self.defense /= 2
                self.specialDefense /= 2
                atk1_output = "\nIt's not very effective..." 
                atk2_output = "\nIt's super effective!"
                 
            #Both Pokemon are the same type
            if Poke_Opponent.type == self.type:
                atk1_output = "\nIt's not very effective..."
                atk2_output = "\nIt's not very effective..."
            
            else:
                atk1_output = "\nIt did damage!"
                atk2_output = "\nIt did damage!"
        
        #ICE    
        if self.type == "Ice":
            #Player1 Pokemon is Super Effective!
            if Poke_Opponent.type == "Grass" or Poke_Opponent.type == "Ground" or Poke_Opponent.type == "Flying" or Poke_Opponent.type == "Dragon":
                self.attack *= 2
                self.specialAttack *= 2
                self.defense *= 2
                self.specialDefense *= 2
                
                Poke_Opponent.attack /= 2
                Poke_Opponent.specialAttack /= 2
                Poke_Opponent.defense /= 2
                Poke_Opponent.specialDefense /= 2
                atk1_output = "\nIt's super effective!"
                atk2_output = "\nIt's not very effective..."
            
            #Player1 Pokemon is not very effective...
            if Poke_Opponent.type == "Water":
                Poke_Opponent.attack *= 2
                Poke_Opponent.specialAttack *= 2
                Poke_Opponent.defense *= 2
                Poke_Opponent.specialDefense *=2 
                
                self.attack /= 2
                self.specialAttack /= 2
                self.defense /= 2
                self.specialDefense /= 2
                atk1_output = "\nIt's not very effective..." 
                atk2_output = "\nIt's super effective!"
                
            #Both Pokemon are the same type
            if Poke_Opponent.type == self.type:
                atk1_output = "\nIt's not very effective..."
                atk2_output = "\nIt's not very effective..."
            
            else:
                atk1_output = "\nIt did damage!"
                atk2_output = "\nIt did damage!"
                
        #FIGHTING     
        if self.type == "Fighting":
            #Player1 Pokemon is Super Effective!
            if Poke_Opponent.type == "Normal" or Poke_Opponent.type == "Ice" or Poke_Opponent.type == "Rock":
                self.attack *= 2
                self.specialAttack *= 2
                self.defense *= 2
                self.specialDefense *= 2
                
                Poke_Opponent.attack /= 2
                Poke_Opponent.specialAttack /= 2
                Poke_Opponent.defense /= 2
                Poke_Opponent.specialDefense /= 2
                atk1_output = "\nIt's super effective!"
                atk2_output = "\nIt's not very effective..."
            
            #Player1 Pokemon is not very effective...
            if Poke_Opponent.type == "Poison" or Poke_Opponent.type == "Flying" or Poke_Opponent.type == "Psychic" or Poke_Opponent.type == "Bug" or Poke_Opponent.type == "Ghost":
                Poke_Opponent.attack *= 2
                Poke_Opponent.specialAttack *= 2
                Poke_Opponent.defense *= 2
                Poke_Opponent.specialDefense *=2 
                
                self.attack /= 2
                self.specialAttack /= 2
                self.defense /= 2
                self.specialDefense /= 2
                atk1_output = "\nIt's not very effective..." 
                atk2_output = "\nIt's super effective!"

                
            #Both Pokemon are the same type
            if Poke_Opponent.type == self.type:
                atk1_output = "\nIt's not very effective..."
                atk2_output = "\nIt's not very effective..."
            
            else:
                atk1_output = "\nIt did damage!"
                atk2_output = "\nIt did damage!"
                
        #Poison  
        if self.type == "Poison":
            #Player1 Pokemon is Super Effective!
            if Poke_Opponent.type == "Grass" or Poke_Opponent.type == "Bug":
                self.attack *= 2
                self.specialAttack *= 2
                self.defense *= 2
                self.specialDefense *= 2
                
                Poke_Opponent.attack /= 2
                Poke_Opponent.specialAttack /= 2
                Poke_Opponent.defense /= 2
                Poke_Opponent.specialDefense /= 2
                atk1_output = "\nIt's super effective!"
                atk2_output = "\nIt's not very effective..."
            
            #Player1 Pokemon is not very effective...
            if Poke_Opponent.type == "Ground" or Poke_Opponent.type == "Rock" or Poke_Opponent.type == "Ghost":
                Poke_Opponent.attack *= 2
                Poke_Opponent.specialAttack *= 2
                Poke_Opponent.defense *= 2
                Poke_Opponent.specialDefense *=2 
                
                self.attack /= 2
                self.specialAttack /= 2
                self.defense /= 2
                self.specialDefense /= 2
                atk1_output = "\nIt's not very effective..." 
                atk2_output = "\nIt's super effective!"
                                
            #Both Pokemon are the same type
            if Poke_Opponent.type == self.type:
                atk1_output = "\nIt's not very effective..."
                atk2_output = "\nIt's not very effective..."
            
            else:
                atk1_output = "\nIt did damage!"
                atk2_output = "\nIt did damage!"
        
        #GROUND    
        if self.type == "Ground":
            #Player1 Pokemon is Super Effective!
            if Poke_Opponent.type == "Fire" or Poke_Opponent.type == "Electric" or Poke_Opponent.type == "Poison" or Poke_Opponent.type == "Rock":
                self.attack *= 2
                self.specialAttack *= 2
                self.defense *= 2
                self.specialDefense *= 2
                
                Poke_Opponent.attack /= 2
                Poke_Opponent.specialAttack /= 2
                Poke_Opponent.defense /= 2
                Poke_Opponent.specialDefense /= 2
                atk1_output = "\nIt's super effective!"
                atk2_output = "\nIt's not very effective..."
            
            #Player1 Pokemon is not very effective...
            if Poke_Opponent.type == "Grass" or Poke_Opponent.type == "Bug" or Poke_Opponent.type == "Flying":
                Poke_Opponent.attack *= 2
                Poke_Opponent.specialAttack *= 2
                Poke_Opponent.defense *= 2
                Poke_Opponent.specialDefense *=2 
                
                self.attack /= 2
                self.specialAttack /= 2
                self.defense /= 2
                self.specialDefense /= 2
                atk1_output = "\nIt's not very effective..." 
                atk2_output = "\nIt's super effective!"

                
            #Both Pokemon are the same type
            if Poke_Opponent.type == self.type:
                atk1_output = "\nIt's not very effective..."
                atk2_output = "\nIt's not very effective..."
            
            else:
                atk1_output = "\nIt did damage!"
                atk2_output = "\nIt did damage!"
        
        #FLYING   
        if self.type == "Flying":
            #Player1 Pokemon is Super Effective!
            if Poke_Opponent.type == "Grass" or Poke_Opponent.type == "Fighting" or Poke_Opponent.type == "Bug":
                self.attack *= 2
                self.specialAttack *= 2
                self.defense *= 2
                self.specialDefense *= 2
                
                Poke_Opponent.attack /= 2
                Poke_Opponent.specialAttack /= 2
                Poke_Opponent.defense /= 2
                Poke_Opponent.specialDefense /= 2
                atk1_output = "\nIt's super effective!"
                atk2_output = "\nIt's not very effective..."
            
            #Player1 Pokemon is not very effective...
            if Poke_Opponent.type == "Electric" or Poke_Opponent.type == "Rock":
                Poke_Opponent.specialAttack *= 2
                Poke_Opponent.defense *= 2
                Poke_Opponent.specialDefense *=2 
                
                self.attack /= 2
                self.specialAttack /= 2
                self.defense /= 2
                self.specialDefense /= 2
                atk1_output = "\nIt's not very effective..." 
                atk2_output = "\nIt's super effective!"
                
            #Both Pokemon are the same type
            if Poke_Opponent.type == self.type:
                atk1_output = "\nIt's not very effective..."
                atk2_output = "\nIt's not very effective..."
            
            else:
                atk1_output = "\nIt did damage!"
                atk2_output = "\nIt did damage!"
                
        #PSYCHIC  
        if self.type == "Psychic":
            #Player1 Pokemon is Super Effective!
            if Poke_Opponent.type == "Fighting" or Poke_Opponent.type == "Poison":
                self.attack *= 2
                self.specialAttack *= 2
                self.defense *= 2
                self.specialDefense *= 2
                
                Poke_Opponent.attack /= 2
                Poke_Opponent.specialAttack /= 2
                Poke_Opponent.defense /= 2
                Poke_Opponent.specialDefense /= 2
                atk1_output = "\nIt's super effective!"
                atk2_output = "\nIt's not very effective..."
            
            #Player1 Pokemon is not very effective...
            if Poke_Opponent.type == "Psychic":
                Poke_Opponent.specialAttack *= 2
                Poke_Opponent.defense *= 2
                Poke_Opponent.specialDefense *=2 
                
                self.attack /= 2
                self.specialAttack /= 2
                self.defense /= 2
                self.specialDefense /= 2
                atk1_output = "\nIt's not very effective..." 
                atk2_output = "\nIt's super effective!"
                            
            else:
                atk1_output = "\nIt did damage!"
                atk2_output = "\nIt did damage!"
        
        #BUG   
        if self.type == "Bug":
            #Player1 Pokemon is Super Effective!
            if Poke_Opponent.type == "Grass" or Poke_Opponent.type == "Poison" or Poke_Opponent.type == "Psychic":
                self.attack *= 2
                self.specialAttack *= 2
                self.defense *= 2
                self.specialDefense *= 2
                
                Poke_Opponent.attack /= 2
                Poke_Opponent.specialAttack /= 2
                Poke_Opponent.defense /= 2
                Poke_Opponent.specialDefense /= 2
                atk1_output = "\nIt's super effective!"
                atk2_output = "\nIt's not very effective..."
            
            #Player1 Pokemon is not very effective...
            if Poke_Opponent.type == "Fire" or Poke_Opponent.type == "Fighting" or Poke_Opponent.type == "Flying" or Poke_Opponent.type == "Ghost":
                Poke_Opponent.specialAttack *= 2
                Poke_Opponent.defense *= 2
                Poke_Opponent.specialDefense *=2 
                
                self.attack /= 2
                self.specialAttack /= 2
                self.defense /= 2
                self.specialDefense /= 2
                atk1_output = "\nIt's not very effective..." 
                atk2_output = "\nIt's super effective!"
                
            #Both Pokemon are the same type
            if Poke_Opponent.type == self.type:
                atk1_output = "\nIt's not very effective..."
                atk2_output = "\nIt's not very effective..."
            
            else:
                atk1_output = "\nIt did damage!"
                atk2_output = "\nIt did damage!"
                
        #ROCK 
        if self.type == "Rock":
            #Player1 Pokemon is Super Effective!
            if Poke_Opponent.type == "Fire" or Poke_Opponent.type == "Ice" or Poke_Opponent.type == "Flying" or Poke_Opponent.type == "Bug":
                self.attack *= 2
                self.specialAttack *= 2
                self.defense *= 2
                self.specialDefense *= 2
                
                Poke_Opponent.attack /= 2
                Poke_Opponent.specialAttack /= 2
                Poke_Opponent.defense /= 2
                Poke_Opponent.specialDefense /= 2
                atk1_output = "\nIt's super effective!"
                atk2_output = "\nIt's not very effective..."
            
            #Player1 Pokemon is not very effective...
            if Poke_Opponent.type == "Fighting" or Poke_Opponent.type == "Ground":
                Poke_Opponent.specialAttack *= 2
                Poke_Opponent.defense *= 2
                Poke_Opponent.specialDefense *=2 
                
                self.attack /= 2
                self.specialAttack /= 2
                self.defense /= 2
                self.specialDefense /= 2
                atk1_output = "\nIt's not very effective..." 
                atk2_output = "\nIt's super effective!"
                
            #Both Pokemon are the same type
            if Poke_Opponent.type == self.type:
                atk1_output = "\nIt's not very effective..."
                atk2_output = "\nIt's not very effective..."
            
            else:
                atk1_output = "\nIt did damage!"
                atk2_output = "\nIt did damage!"
                
        #GHOST  
        if self.type == "Ghost":
            #Player1 Pokemon is Super Effective!
            if Poke_Opponent.type == "Ghost":
                self.attack *= 2
                self.specialAttack *= 2
                self.defense *= 2
                self.specialDefense *= 2
                
                Poke_Opponent.attack /= 2
                Poke_Opponent.specialAttack /= 2
                Poke_Opponent.defense /= 2
                Poke_Opponent.specialDefense /= 2
                atk1_output = "\nIt's super effective!"
                atk2_output = "\nIt's not very effective..."
            
            #Player1 Pokemon is not very effective...
            if Poke_Opponent.type == "Normal" or Poke_Opponent.type == "Psychic":
                Poke_Opponent.specialAttack *= 2
                Poke_Opponent.defense *= 2
                Poke_Opponent.specialDefense *=2 
                
                self.attack /= 2
                self.specialAttack /= 2
                self.defense /= 2
                self.specialDefense /= 2
                atk1_output = "\nIt's not very effective..." 
                atk2_output = "\nIt's super effective!"
                
            #Both Pokemon are the same type
            if Poke_Opponent.type == self.type:
                atk1_output = "\nIt's not very effective..."
                atk2_output = "\nIt's not very effective..."
            
            else:
                atk1_output = "\nIt did damage!"
                atk2_output = "\nIt did damage!"
                
        #DRAGON   
        if self.type == "Dragon":
            #Player1 Pokemon is Super Effective!
            if Poke_Opponent.type == "Dragon":
                self.attack *= 2
                self.specialAttack *= 2
                self.defense *= 2
                self.specialDefense *= 2
                
                Poke_Opponent.attack /= 2
                Poke_Opponent.specialAttack /= 2
                Poke_Opponent.defense /= 2
                Poke_Opponent.specialDefense /= 2
                atk1_output = "\nIt's super effective!"
                atk2_output = "\nIt's super effective!"
            
            else:
                atk1_output = "\nIt did damage!"
                atk2_output = "\nIt did damage!"
                
        #Fighting Code
        
        #if self.speed > Poke_Opponent.speed:
            
        while((self.healthbar > 0) and (Poke_Opponent.healthbar > 0) ):
            
            print(f"\n{self.name}\t\tHP\t{self.health}")
            print(f"\n{Poke_Opponent.name}\t\tHP\t{Poke_Opponent.health}")
            
            print(f"Go {self.name}!")
            for i, x in enumerate(self.moves):
                print(f"{i+1}.", x)
            index = int(input('Pick a move: '))
            delayPrint(f"\n{self.name} used {self.moves[index-1]}!")
            time.sleep(1)
            delayPrint(atk1_output)
            
            #Player ATTACK
            Poke_Opponent.healthbar -= self.attack
            Poke_Opponent.health = ""
            
            # Add back bars plus defense boost
            for j in range(int(Poke_Opponent.healthbar+.1*Poke_Opponent.defense)):
                Poke_Opponent.health += "="
                
            time.sleep(2)
            
            print(f"\n{self.name}\t\tHP\t{self.health}")
            print(f"{Poke_Opponent.name}\t\tHP\t{Poke_Opponent.health}\n")
            time.sleep(.5)
            
            
            #CHECK IF Poke_Opponent FAINTED
            if Poke_Opponent.healthbar <= 0:
                delayPrint(f"\n{Poke_Opponent.name} has fainted...")
                break
                
            #Poke_Opponent Turn Automated
            
            print(f"Go {Poke_Opponent.name}!")
            
            rand_move = rand.randint(1,4)
            
            delayPrint(f"\n{Poke_Opponent.name} used {Poke_Opponent.moves[rand_move-1]}!")
            time.sleep(1)
            delayPrint(atk2_output)
            
            #Poke_Opponent ATTACK
            self.healthbar -= Poke_Opponent.attack
            self.health = ""
            
            # Add back bars plus defense boost
            for j in range(int(self.healthbar+.1*self.defense)):
                self.health += "="
                
            time.sleep(2)
            
            print(f"\n{self.name}\t\tHP\t{self.health}")
            print(f"{Poke_Opponent.name}\t\tHP\t{Poke_Opponent.health}\n")
            time.sleep(.5)
            
            
            #CHECK IF Player FAINTED
            if self.healthbar <= 0:
                delayPrint(f"\n{self.name} has fainted...")
                break

# %%
if __name__ == "__main__":
    Charizard = Pokemon('Charizard', 'Fire',['Flamethrower', 'Fly', 'Blast Burn', 'Fire Punch'],
                        {'Attack':12,'Special Attack':6,'Defense':10,'Special Defense':3,'Speed':11})
    Blastoise = Pokemon("Blastoise",'Water',['Water Gun', 'Bubblebeam', 'Hydro Pump', 'Surf'],
                       {'Attack':9,'Special Attack':4,'Defense':16,'Special Defense':8,'Speed':8})
    Blastoise.battle(Charizard)
# Out:
# -----POKEMON BATTLE-----
#
# Blastoise
#
# TYPE-> Water
# ATTACK:  9
# SPECIAL ATTACK:  4
# SPECIAL DEFENSE:  8
# DEFENSE:  16
# SPEED:  8
# Lv.  30.0
# VS
# Charizard
#
# TYPE-> Fire
# ATTACK:  12
# SPECIAL ATTACK:  6
# SPECIAL DEFENSE:  3
# DEFENSE:  10
# SPEED:  11
# Lv.  28.200000000000003
#
# Blastoise		HP	=========================
#
# Charizard		HP	=========================
# Go Blastoise!
# 1. Water Gun
# 2. Bubblebeam
# 3. Hydro Pump
# 4. Surf
# Pick a move: 1
#
# Blastoise used Water Gun!
# It did damage!
# Blastoise		HP	=========================
# Charizard		HP	=======
#
# Go Charizard!
#
# Charizard used Flamethrower!
# It did damage!
# Blastoise		HP	======================
# Charizard		HP	=======
#
#
# Blastoise		HP	======================
#
# Charizard		HP	=======
# Go Blastoise!
# 1. Water Gun
# 2. Bubblebeam
# 3. Hydro Pump
# 4. Surf
# Pick a move: 3
#
# Blastoise used Hydro Pump!
# It did damage!
# Blastoise		HP	======================
# Charizard		HP
#
#
# ...

# %%
print(j)
# Out:
# 4
